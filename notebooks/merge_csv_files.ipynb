# %% [markdown]
# # Description
# 1. Merges files links_N.csv into one file **links.csv**
# 2. Merges files data_N.csv into one file ***data.csv***

# %% [markdown]
# # Import

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Settings

# %%
LINKS_NUM = 3
DATA_NUM = 20
DIR = '/content/drive/MyDrive/Colab Notebooks/DAN/feedback_tracking/files'

# %% [markdown]
# # Merge **links csv** files

# %%
df_1 = pd.read_csv(f'{DIR}/links_1.csv', index_col=0)
df_2 = pd.read_csv(f'{DIR}/links_2.csv', index_col=0)
df_3 = pd.read_csv(f'{DIR}/links_3.csv', index_col=0)

# %%
print(df_1.shape, df_2.shape, df_3.shape)
# Out:
# (5770, 4) (8090, 4) (5173, 4)

# %%
df = pd.concat([df_1, df_2, df_3])
print(df.shape)
# Out:
# (19033, 4)

# %% [markdown]
# ## Save dataset

# %%
file_path = f'{DIR}/links.csv'
df.to_csv(file_path, index=False)

# %%
df.head(5)
# Out:
#        id                             link         bank  rating
# 0  536617       /bank/tochka/otzyvy/536617       tochka       5
# 1  536578  /bank/gazprombank/otzyvy/536578  gazprombank       5
# 2  536577  /bank/gazprombank/otzyvy/536577  gazprombank       5
# 3  536567  /bank/gazprombank/otzyvy/536567  gazprombank       5
# 4  536564  /bank/gazprombank/otzyvy/536564  gazprombank       5

# %% [markdown]
# # Merge **data csv** files

# %%
data_list = []
for i in range(DATA_NUM):
  df_i = pd.read_csv(f'{DIR}/data_{i}.csv', index_col=0)
  data_list.append(df_i)

df = pd.concat(data_list)

# %%
print(df.shape)
# Out:
# (19524, 4)

# %% [markdown]
# ## Save dataset

# %%
file_path = f'{DIR}/data.csv'
df.to_csv(file_path, index=False)

# %%
df.head(5)
# Out:
#        id                                               text         bank  \
# 0  536617  Очень довольны работой банка Работаем с "Точко...       tochka
# 1  536578  Взять кредит— элементарно! Форма заявки элемен...  gazprombank
# 2  536577  Банк №1 в России Мы с мужем клиенты с 2019 год...  gazprombank
# 3  536567  Банк и карточка для жизни Потому что все удобн...  gazprombank
# 4  536564  Реклама кредита точно сработала Последний меся...  gazprombank
#
#    rating
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
